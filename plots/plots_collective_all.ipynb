# %%
#%pip install rdflib
from rdflib import *
whataGraph = Graph()
whataGraph.parse("all_amrs.ttl", format="ttl")
# Out:
# <Graph identifier=N09e2673ac3b0467392b6ad741713ea10 (<class 'rdflib.graph.Graph'>)>

# %%
#what does a blamable eventuality involve?
cqblended = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {
# ?s a whata:Ought.
  # ?s whata:isParticipantIn ?blended.
  # ?blended a whata:BlendedBlameBackground.
}
      
"""
results = whataGraph.query(cqblended)
list3=list()
for row in results:
    list3.append(row)
    print(row)
print( len (list3))
# Out:
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#lose_1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#MoralJudgment'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtAltRight'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtAltLeft'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtWe'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtYourSide'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#Ought_1'),)
# ...

# %%
#what does a blamable eventuality involve?
cqblendedro = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {
# ?s a whata:ResponsibilityOwner.
  # ?s whata:isParticipantIn ?blended.
  # ?blended a whata:BlendedBlameBackground.
}
      
"""
results = whataGraph.query(cqblendedro)
listro3=list()
for row in results:
    listro3.append(row)
    print(row)
print( len (listro3))
# Out:
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#doctor'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ill_person'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner2'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#US'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#person_1'),)
# ...

# %%
#what does a blamable eventuality involve?
cqblamable = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s 
WHERE {
 # ?s a whata:Ought.
  # ?s whata:isParticipantIn ?b.
  
  # ?b a whata:Blamable.
}
      
"""
results = whataGraph.query(cqblamable)
list1=list()
for row in results:
    list1.append(row)
    print(row)
print(len(list1))
# Out:
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#lose_1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#MoralJudgment'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtAltRight'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtWe'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#Ought_1'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#right_2'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#climate_1'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#stop_1'),)
# ...

# %%
#what does a blamable eventuality involve?
cqbl = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {
# ?s a whata:ResponsibilityOwner.
  # ?s whata:isParticipantIn ?b.
  # ?b a whata:Blamable.
}
      
"""
results = whataGraph.query(cqbl)
listro1=list()
for row in results:
    listro1.append(row)
    print(row)
print( len (listro1))
# Out:
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ill_person'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#person_1'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#Yale'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#country_1'),)
# ...

# %%
#what does a blamable eventuality involve?
cqc_blamable = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {
# ?s a whata:Ought.
  # ?s whata:isParticipantIn ?b.
  # ?b a whata:CounterBlamable.
}
      
"""
results = whataGraph.query(cqc_blamable)
list2=list()
for row in results:
    list2.append(row)
print(len(list2))
# Out:
# 15

# %%
#what does a blamable eventuality involve?
cqc_ro = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {
# ?s a whata:ResponsibilityOwner.
  # ?s whata:isParticipantIn ?bl.
  # ?bl a whata:CounterBlamable.
}
      
"""
results = whataGraph.query(cqc_ro)
listro2=list()
for row in results:
    listro2.append(row)
    print(row)
print( len (listro2))
# Out:
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#doctor'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner2'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner2'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#US'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#Yale'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#person_emit'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#man_1'),)
# ...

# %%
# %pip install matplotlib_venn

# %%
set1=set(list1)
set2=set(list2)
set3=set(list3)
print (set1, set2, set3)
# Out:
# {(rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#food_1'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#climate_1'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#safe_1'),), (rdflib.term.URIRef('https://w3id.org/framester/pb/data/clean-01'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#climate_1'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#right_2'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtWe'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ought_10'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#stop_1'),), (rdflib.term.URIRef('http://www.ontologydesignpatte
# ...

# %%
# Function to extract the part after the last #
def extract_label(uri):
    return str(uri).split('#')[-1]

# Extract labels
set1_labels = {extract_label(uri[0]) for uri in set1}
set2_labels = {extract_label(uri[0]) for uri in set2}
set3_labels = {extract_label(uri[0]) for uri in set3}

# %%
print(set1_labels,set2_labels,set3_labels)
# Out:
# {'climate_1', 'ought_10', 'food_1', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'stop_1', 'OughtAltRight', 'Air', 'OughtWe', 'lose_1', 'Ought_1', 'effective_1', 'MoralJudgment'} {'climate_1', 'Ought_2', 'ought_10', 'OughtAltLeft', 'OughtYourSide', 'farm_2', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'stop_1', 'Air', 'lose_1', 'MoralJudgment', 'victim_1'} {'climate_1', 'OughtYourSide', 'food_1', 'OughtAltLeft', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'lose_1', 'MoralJudgment', 'Ought_2', 'ought_10', 'OughtAltRight', 'farm_2', 'OughtWe', 'Ought_1', 'stop_1', 'Air', 'effective_1', 'victim_1'}

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn3



# Increase the dimensions of the plot
plt.figure(figsize=(10, 10))

# Create a Venn diagram
venn_diagram = venn3([set1_labels, set2_labels, set3_labels], set_labels=('Blamable', 'CounterBlamable', 'Blended'))

# Customize the labels to show the elements instead of counts
if venn_diagram.get_label_by_id('100'):
    venn_diagram.get_label_by_id('100').set_text(',\n '.join(map(str, set1_labels - set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('010'):
    venn_diagram.get_label_by_id('010').set_text(',\n '.join(map(str, set2_labels - set1_labels - set3_labels)))
if venn_diagram.get_label_by_id('001'):
    venn_diagram.get_label_by_id('001').set_text(',\n '.join(map(str, set3_labels - set1_labels - set2_labels)))
if venn_diagram.get_label_by_id('110'):
    venn_diagram.get_label_by_id('110').set_text(',\n '.join(map(str, set1_labels & set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('101'):
    venn_diagram.get_label_by_id('101').set_text(',\n '.join(map(str, set1_labels & set3_labels - set2_labels)))
if venn_diagram.get_label_by_id('011'):
    venn_diagram.get_label_by_id('011').set_text(',\n '.join(map(str, set2_labels & set3_labels - set1_labels)))
if venn_diagram.get_label_by_id('111'):
    venn_diagram.get_label_by_id('111').set_text(',\n '.join(map(str, set1_labels & set2_labels & set3_labels)))

# Show the plot
plt.title("Venn Diagram of Responsibility Owner instances in the Blamable, CounterBlamable and Blended Space")
plt.show()

# %% [markdown]
# ### Oughts

# %%
# Function to extract the part after the last #
def extract_label(uri):
    return str(uri).split('#')[-1]


set1=set(listro1)
set2=set(listro2)
set3=set(listro3)
print (set1, set2, set3)
# Extract labels
set1_labels = {extract_label(uri[0]) for uri in set1}
set2_labels = {extract_label(uri[0]) for uri in set2}
set3_labels = {extract_label(uri[0]) for uri in set3}
# Out:
# {(rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ill_person'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#PenaltyResponsibilityOwner'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#person_party_member'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#person_0'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#Yale'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#person_2'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#country_1'),),
# ...

# %%
print(set1_labels,set2_labels,set3_labels)
# Out:
# {'ResponsibilityOwner1', 'They', 'person_1', 'ro1', 'DieselCar', 'person_0', 'ill_person', 'Yale', 'person_party_member', 'person_2', 'Billy', 'country_1', 'PenaltyResponsibilityOwner'} {'They', 'Yale', 'person_car_owner', 'doctor', 'US', 'Bobby', 'person_2', 'man_1', 'ResponsibilityOwner2', 'PetrolCar', 'Robert_Mugabe', 'person_bigot', 'person_emit'} {'ResponsibilityOwner2', 'PenaltyResponsibilityOwner', 'ResponsibilityOwner1', 'ro1', 'PetrolCar', 'Billy', 'person_bigot', 'person_emit', 'Robert_Mugabe', 'person_1', 'DieselCar', 'ill_person', 'person_party_member', 'Bobby', 'person_2', 'country_1', 'They', 'person_0', 'Yale', 'person_car_owner', 'doctor', 'US', 'man_1'}

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn3



# Increase the dimensions of the plot
plt.figure(figsize=(10, 10))

# Create a Venn diagram
venn_diagram = venn3([set1_labels, set2_labels, set3_labels], set_labels=('Blamable', 'CounterBlamable', 'Blended'))

# Customize the labels to show the elements instead of counts
if venn_diagram.get_label_by_id('100'):
    venn_diagram.get_label_by_id('100').set_text(',\n '.join(map(str, set1_labels - set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('010'):
    venn_diagram.get_label_by_id('010').set_text(',\n '.join(map(str, set2_labels - set1_labels - set3_labels)))
if venn_diagram.get_label_by_id('001'):
    venn_diagram.get_label_by_id('001').set_text(',\n '.join(map(str, set3_labels - set1_labels - set2_labels)))
if venn_diagram.get_label_by_id('110'):
    venn_diagram.get_label_by_id('110').set_text(',\n '.join(map(str, set1_labels & set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('101'):
    venn_diagram.get_label_by_id('101').set_text(',\n '.join(map(str, set1_labels & set3_labels - set2_labels)))
if venn_diagram.get_label_by_id('011'):
    venn_diagram.get_label_by_id('011').set_text(',\n '.join(map(str, set2_labels & set3_labels - set1_labels)))
if venn_diagram.get_label_by_id('111'):
    venn_diagram.get_label_by_id('111').set_text(',\n '.join(map(str, set1_labels & set2_labels & set3_labels)))

# Show the plot
plt.title("Venn Diagram of Ought instances in the Blamable, CounterBlamable and Blended Space")
plt.show()

# %%
#what does a blamable eventuality involve?
cqblended = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {

  # ?s whata:isParticipantIn ?blended.
  # ?blended a whata:BlendedBlameBackground.
}
      
"""
results = whataGraph.query(cqblended)
list3=list()
for row in results:
    list3.append(row)
    print(row)
print( len (list3))
# Out:
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#doctor'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ill_person'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#lose_1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#MoralJudgment'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner2'),)
# ...

# %%
#what does a blamable eventuality involve?
cqblamable = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s 
WHERE {
 
  # ?s whata:isParticipantIn ?b.
  
  # ?b a whata:Blamable.
}
      
"""
results = whataGraph.query(cqblamable)
list1=list()
for row in results:
    list1.append(row)
    print(row)
print(len(list1))
# Out:
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ill_person'),)
# (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#lose_1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#MoralJudgment'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#OughtAltRight'),)
# (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ResponsibilityOwner1'),)
# ...

# %%
#what does a blamable eventuality involve?
cqc_blamable = """PREFIX whata:<https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#> 
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX per:<http://www.ontologydesignpatterns.org/ont/persp/perspectivisation.owl#>
    PREFIX dns: <http://www.ontologydesignpatterns.org/cp/owl/description.owl#>
SELECT  ?s
WHERE {

  # ?s whata:isParticipantIn ?b.
  # ?b a whata:CounterBlamable.
}
      
"""
results = whataGraph.query(cqc_blamable)
list2=list()
for row in results:
    list2.append(row)
print(len(list2))
# Out:
# 30

# %%
set1=set(list1)
set2=set(list2)
set3=set(list3)
print (set1, set2, set3)
# Out:
# {(rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#They'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#right_2'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#Yale'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#stop_1'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#DieselCar'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#ro1'),), (rdflib.term.URIRef('http://www.ontologydesignpatterns.org/ont/fred/domain.owl#food_1'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_ontology.owl#PenaltyResponsibilityOwner'),), (rdflib.term.URIRef('https://raw.githubusercontent.com/Salvadana/whata_ontology/main/ontology_development/whata_on
# ...

# %%
# Function to extract the part after the last #
def extract_label(uri):
    return str(uri).split('#')[-1]

# Extract labels
set1_labels = {extract_label(uri[0]) for uri in set1}
set2_labels = {extract_label(uri[0]) for uri in set2}
set3_labels = {extract_label(uri[0]) for uri in set3}

# %%
print(set1_labels,set2_labels,set3_labels)
# Out:
# {'climate_1', 'food_1', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'lose_1', 'MoralJudgment', 'PenaltyResponsibilityOwner', 'ResponsibilityOwner1', 'ro1', 'ought_10', 'OughtAltRight', 'Billy', 'person_1', 'DieselCar', 'ill_person', 'person_party_member', 'person_2', 'OughtWe', 'country_1', 'Ought_1', 'Blended', 'They', 'person_0', 'Yale', 'stop_1', 'Air', 'effective_1'} {'climate_1', 'OughtYourSide', 'OughtAltLeft', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'ResponsibilityOwner2', 'lose_1', 'MoralJudgment', 'Ought_2', 'ought_10', 'PetrolCar', 'person_bigot', 'Robert_Mugabe', 'person_emit', 'farm_2', 'Bobby', 'person_2', 'Blended', 'They', 'Yale', 'person_car_owner', 'doctor', 'US', 'stop_1', 'man_1', 'Air', 'victim_1'} {'climate_1', 'OughtYourSide', 'food_1', 'OughtAltLeft', 'safe_1', 'https://w3id.org/framester/pb/data/clean-01', 'right_2', 'ResponsibilityOwner2', 'lose_1', 'MoralJudgment', 'PenaltyResponsibilityOwner', 'Responsibil
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn3



# Increase the dimensions of the plot
plt.figure(figsize=(10, 10))

# Create a Venn diagram
venn_diagram = venn3([set1_labels, set2_labels, set3_labels], set_labels=('Blamable', 'CounterBlamable', 'Blended'))


# Set colors for each subset

# Customize the labels to show the elements instead of counts
if venn_diagram.get_label_by_id('100'):
    venn_diagram.get_label_by_id('100').set_text(',\n '.join(map(str, set1_labels - set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('010'):
    venn_diagram.get_label_by_id('010').set_text(',\n '.join(map(str, set2_labels - set1_labels - set3_labels)))
if venn_diagram.get_label_by_id('001'):
    venn_diagram.get_label_by_id('001').set_text(',\n '.join(map(str, set3_labels - set1_labels - set2_labels)))
if venn_diagram.get_label_by_id('110'):
    venn_diagram.get_label_by_id('110').set_text(',\n '.join(map(str, set1_labels & set2_labels - set3_labels)))
if venn_diagram.get_label_by_id('101'):
    venn_diagram.get_label_by_id('101').set_text(',\n '.join(map(str, set1_labels & set3_labels - set2_labels)))
if venn_diagram.get_label_by_id('011'):
    venn_diagram.get_label_by_id('011').set_text(',\n '.join(map(str, set2_labels & set3_labels - set1_labels)))
if venn_diagram.get_label_by_id('111'):
    venn_diagram.get_label_by_id('111').set_text(',\n '.join(map(str, set1_labels & set2_labels & set3_labels)))

# Show the plot
plt.title("Venn Diagram of Responsibility Owner instances in the Blamable, CounterBlamable and Blended Space")
plt.show()
